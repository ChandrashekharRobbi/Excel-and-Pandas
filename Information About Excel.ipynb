# %% [markdown]
# ### Let's Understand the basics of Excel

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Untitled-2023-09-05-2035.png](attachment:Untitled-2023-09-05-2035.png)

# %% [markdown]
# ![HOME.png](attachment:HOME.png)

# %% [markdown]
# ![INSERT.png](attachment:INSERT.png)

# %% [markdown]
# ![PAGE.png](attachment:PAGE.png)
